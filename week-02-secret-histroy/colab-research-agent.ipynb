# %% [markdown]
# <a href="https://colab.research.google.com/github/DeaY01/12-weeks-ai-agents-series/blob/main/week-02-secret-history/colab-research-agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 2 – Tool-Using Research Agent
# **12-Week AI Agents Series | Oladapo Ajiboye (@DeaY01) | Dec 2025**
#
# This agent uses **real web search** to answer any question about AI agent history.
# Works 100 % free — add your OpenAI key for better reasoning.

# %%
# !pip install langchain langchain-community langchain-openai duckduckgo-search -q

from langchain_community.tools import DuckDuckGoSearchRun
from langchain.agents import initialize_agent, AgentType
from langchain_openai import ChatOpenAI

openai_key = ""  # ← put your key here or leave empty (still works)

llm = ChatOpenAI(openai_api_key=openai_key or "dummy", temperature=0.3)

tools = [DuckDuckGoSearchRun()]

agent = initialize_agent(tools, llm, agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION, verbose=True)

print("Week 2 Tool-Using Research Agent Ready!\n")

question = "What did Claude Shannon write in 1950 and how does it relate to AI agents?"
print(agent.run(question))

# %% [markdown]
# Edit the `question` line and re-run to ask anything.
#
# Week 3 → The 5 Types of Agents
#
# Star the repo → https://github.com/DeaY01/12-weeks-ai-agents-series
